# %%
import requests
import utilities as u
from utilities import import_raw_data
import pandas as pd
import os

pd.set_option("display.max_columns", None)
pd.set_option("display.precision", 2)

# %%
# import requests

season = '2223'
league = ['I1' , 'E0']

for i in league:
    u.import_raw_data(season, i )
# Out:
# https://www.football-data.co.uk/mmz4281/2223/I1.csv
# Salvo i file in H:\Il mio Drive\serie a\python\football-data.com\raw_data
# https://www.football-data.co.uk/mmz4281/2223/E0.csv
# Salvo i file in H:\Il mio Drive\serie a\python\football-data.com\raw_data

# %%
os.getcwd()
df = pd.read_csv("raw_data\\I1.csv")
df.head(5)
# Out:
#   Div        Date   Time    HomeTeam   AwayTeam  FTHG  FTAG FTR  HTHG  HTAG  \
# 0  I1  13/08/2022  17:30       Milan    Udinese     4     2   H     2     2
# 1  I1  13/08/2022  17:30   Sampdoria   Atalanta     0     2   A     0     1
# 2  I1  13/08/2022  19:45       Lecce      Inter     1     2   A     0     1
# 3  I1  13/08/2022  19:45       Monza     Torino     1     2   A     0     1
# 4  I1  14/08/2022  17:30  Fiorentina  Cremonese     3     2   H     2     1
#
#   HTR  HS  AS  HST  AST  HF  AF  HC  AC  HY  AY  HR  AR  B365H  B365D  B365A  \
# 0   D  14   9    5    4  16  13   5   1   1   4   0   0   1.44   4.75   7.00
# 1   A  11   9    1    3  13  21   3   2   4   6   0   0   4.33   3.90   1.75
# 2   A  10  19    4    9  21  19   6   8   4   2   0   0  10.00   5.75   1.28
# 3   A  15  13    4    6   6  17   2   7   1   2   0   0   2.60   3.30   2.75
# 4   H  27  13   11    4  10  19  11   4   0   3   0   1   1.36   5.00   8.50
#
# ...

# %%
squadra_h = pd.DataFrame({'squadra': df['HomeTeam'].unique()} )
squadra_a = pd.DataFrame(df['AwayTeam'].unique())

# %%
squadra_h.head()
# Out:
#       squadra
# 0       Milan
# 1   Sampdoria
# 2       Lecce
# 3       Monza
# 4  Fiorentina

# %%
df.count()
# Out:
# Div         380
# Date        380
# Time        380
# HomeTeam    380
# AwayTeam    380
#            ...
# PCAHA       380
# MaxCAHH     380
# MaxCAHA     380
# AvgCAHH     380
# AvgCAHA     380
# Length: 105, dtype: int64

# %%
os.getcwd()
# Out:
# 'H:\\Il mio Drive\\serie a\\python\\football-data.com'

# %%
df_list = []
input_dir= "raw_data"
for file in os.listdir(input_dir):
    if file.endswith('.csv'):
        print(str(file[:2]))
        # global(file[:2]) = pd.read_csv(os.path.join(input_dir, file))
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Input In [47], in <cell line: 3>()
#       1 df_list = []
#       2 input_dir= "raw_data"
# ----> 3 for file in os.listdir(input_dir):
#       4     if file.endswith('.csv'):
#       5         print(str(file[:2]))
#
# OSError: [WinError 433] È stato specificato un dispositivo inesistente: 'raw_data'
