# %%
import requests
import re
from bs4 import BeautifulSoup
import pandas as pd
import html5lib
import time
pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", None)
pd.set_option("display.precision", 2)
# pd.set_option("display.freeze_panes", 1)
from datetime import datetime
now = datetime.now()
print(now.strftime('%d/%m/%Y %H:%M:%S'))
import utilities
from utilities import convert_season 
from utilities import get_final_links
# Out:
# 29/09/2023 18:57:53

# %%
standings_url = f"https://www.decathlon.it/"
# print(str(data))
data = requests.get(standings_url )
str(data)
soup = BeautifulSoup(data.text , 'html.parser')
standings_table = soup.find_all("link")# , {"href": re.compile("/tennis")})

# %%
standings_table
# Out:
# [<link href="https://contents.mediadecathlon.com" rel="preconnect"/>,
#  <link href="/render/favicon-16x16.5b96aec8a3db881722a5.png" rel="icon" sizes="16x16" type="image/png"/>,
#  <link href="/render/favicon-32x32.3609b48e189586b5c5ee.png" rel="icon" sizes="32x32" type="image/png"/>,
#  <link href="/render/favicon-96x96.1d72df8f08484c5c2852.png" rel="icon" sizes="96x96" type="image/png"/>,
#  <link href="/render/android-icon-192x192.47c610ae67c1b1bdc694.png" rel="icon" sizes="192x192" type="image/png"/>,
#  <link href="/render/apple-icon-57x57.4d9bc3316c9ad2c3cb03.png" rel="apple-touch-icon" sizes="57x57"/>,
#  <link href="/render/apple-icon-60x60.8ee1bacdb1a6a6b0af5a.png" rel="apple-touch-icon" sizes="60x60"/>,
#  <link href="/render/apple-icon-72x72.c92851c83aee1c886e40.png" rel="apple-touch-icon" sizes="72x72"/>,
#  <link href="/render/apple-icon-76x76.ed23e4d4b7571c063c34.png" rel="apple-touch-icon" sizes="76x76"/>,
# ...

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html country="IT" lang="it">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=Edge,chrome=1" http-equiv="X-UA-Compatible">
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0" name="viewport"/>
# <link href="https://contents.mediadecathlon.com" rel="preconnect"/>
# <link href="/render/favicon-16x16.5b96aec8a3db881722a5.png" rel="icon" sizes="16x16" type="image/png"/>
# <link href="/render/favicon-32x32.3609b48e189586b5c5ee.png" rel="icon" sizes="32x32" type="image/png"/>
# <link href="/render/favicon-96x96.1d72df8f08484c5c2852.png" rel="icon" sizes="96x96" type="image/png"/>
# <link href="/render/android-icon-192x192.47c610ae67c1b1bdc694.png" rel="icon" sizes="192x192" type="image/png"/>
# <link href="/render/apple-icon-57x57.4d9bc3316c9ad2c3cb03.png" rel="apple-touch-icon" sizes="57x57"/>
# <link href="/render/apple-icon-60x60.8ee1bacdb1a6a6b0af5a.png" rel="apple-touch-icon" sizes="60x60"/>
# ...
