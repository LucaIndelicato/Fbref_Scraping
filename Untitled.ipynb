# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd, numpy as np
import html5lib
import time
import pickle
pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", None)
pd.set_option("display.precision", 2)
# pd.set_option("display.freeze_panes", 1)
from datetime import datetime
now = datetime.now()
print(now.strftime('%d/%m/%Y %H:%M:%S'))
import utilities
from utilities import convert_season 
from utilities import get_final_links

# standings_url = "https://fbref.com/en/comps/11/Serie-A-Stats"
# standings_url = f"https://fbref.com/en/comps/{division}"

def rename_cols(topic_kpi , word : str):
    return [word + i if not i.lower() in ('date', 'opponent') else i for i in topic_kpi]

season = [ '2023-2024' ]
division = [ '11/Serie-A-Stats'  ] #  ,'12/La-Liga-Stats' , '9/Premier-League-Stats'
final_links = []

all_matches = pd.DataFrame()
shoot_kpi = ["Date", "Opponent", "Sh", "SoT", "Dist", "FK", "PK", "PKatt"]
# kpi = []
poss_kpi = ['Date' ,"Opponent",  'Touches', 'Def Pen', 'Def 3rd', 'Mid 3rd','Att 3rd', 'Att Pen', 'Live',
            'Att', 'Succ', 'Succ%', 'Tkld', 'Tkld%','Carries', 'TotDist', 'PrgDist', 'PrgC', 
            '1/3', 'CPA', 'Mis', 'Dis','Rec', 'PrgR']
pass_kpi = ['Date' , "Opponent", 'Total_Cmp', 'Total_Att', 'Total_Cmp%', 'Total_TotDist', 'Total_PrgDist', 
                 'Short_Cmp', 'Short_Att', 'Short_Cmp%',
                 'Medium_Cmp', 'Medium_Att', 'Medium_Cmp%', 
                 'Long_Cmp', 'Long_Att', 'Long_Cmp%', 
                 'Ast', 'xAG', 'xA', 'KP', '1/3', 'PPA', 'CrsPA', 'PrgP']

# for year in years:
for stagione in season:
    for campionato in division:

        print((stagione , campionato) , '\n' )
        standings_url = f"https://fbref.com/en/comps/{campionato}"
        print(standings_url , '\n')
        data = requests.get(standings_url )
        soup = BeautifulSoup(data.text)
        standings_table = soup.select('table.stats_table')[0]
        #dal contenuto isolato su stats_table andiamo ad estrarre i link che contengono i dati di kpi èer singola partita (i dati sono pèresenti a bh)
        links = [ l.get("href") for l in standings_table.find_all('a') ]
        links_squads = [l for l in links if '/squads/' in l]
        # print(links_squads[0:2])
        

        final_links = get_final_links(links_squads, stagione)
        # print(final_links)

        team_urls = [f"https://fbref.com/{l}" for l in final_links]
#         # team_urls = [  "https://fbref.com/en/squads/d609edc0/2022-2023/Empoli-Stats" ,"https://fbref.com/en/squads/d609edc0/2022-2023/Internazionale-Stats" ]

    #     ciclo for sulle squadre
        for i in range(0 , len(team_urls)):
            # print(team_url)
            # print(now.strftime('%Y/%m/%d/ %H:%M'))
            print(team_urls[i])       

            team_name = team_urls[i].split("/")[-1].replace("-Stats", "").replace("-", " ")
            # print(team_urls[i])
            data = requests.get(team_urls[i])
            print("Calling " , team_urls[i] , " result: " , str(data), '\n')

            if str(data) !='<Response [200]>':
                print("Call Problem with : " , team_urls[i] ,  " error: ", str(data))
                continue
    #         print(now.strftime('%Y/%m/%d/ %H:%M') , str(data))
            print("Step 1: matches data for: ", f'{team_name}' ,'\n')
            matches = pd.read_html(data.text, match="Scores & Fixtures")[0] #tabella base delle partite
            matches['season'] =  stagione
            matches['campionato'] = campionato
            matches['team'] =  team_name
            print("Step 1 ended:", f'{team_name}'  ,'\n')
            # print(matches.head())
            # matches.head()
            
            print("Step 2: shoots data for: ", f'{team_name}'  ,'\n')
            soup = BeautifulSoup(data.text)
            links = [l.get("href") for l in soup.find_all('a')]           
            # creiamo i kpi dei topic [shooting , possession , passes] per ogni squadra
            links_shoot = [l for l in links if l and 'all_comps/shooting/' in l]  
            links_shoot
            data_shoot = requests.get(f"https://fbref.com{links_shoot[0]}")

            shooting = pd.read_html(data_shoot.text, match="Shooting")[0]
            shooting.columns = shooting.columns.droplevel()
            shooting = shooting[shoot_kpi]
            shooting.columns = rename_cols(shoot_kpi , 'shoot_')
            print("Step 2 ended:", f'{team_name}'  ,'\n')
            

            print("Step 3: possession data for: ", f'{team_name}'  ,'\n')
            links_poss = [l for l in links if l and 'all_comps/possession/' in l]
            data_poss = requests.get(f"https://fbref.com{links_poss[0]}")

            possession = pd.read_html(data_poss.text, match="Possession")[0]
            possession.columns = possession.columns.droplevel()
            possession = possession[poss_kpi]
            possession.columns = rename_cols(poss_kpi , 'poss_')
            print("Step 3 ended:", f'{team_name}'  ,'\n')

            print("Step 4: passes data for: ", f'{team_name}'  ,'\n')
            links_pass = [l for l in links if l and 'all_comps/passing/' in l]
            data_pass = requests.get(f"https://fbref.com{links_pass[0]}")
            # passes ha un problema di duplicazione nomi colonne :
            # rinominare le cols con numeri e poi rinominare selezionanndo quelle d'iteresse definite in pass_kpi
            passes = pd.read_html(data_pass.text, match="Passing")[0]
            passes.columns = passes.columns.droplevel()
            col = [str(i) for i in range(0, len(passes.columns))]
            passes.columns = col
            passes = passes.iloc[: , [0, *range(9, 32)]]
            passes.columns = pass_kpi
            passes.columns = rename_cols(poss_kpi , 'pass_')
            print("Step 4 ended:", f'{team_name}'  ,'\n')

    #     # unisco i topic kpi lasciando solo una colonna 'Date' : .drop(columns='Date')
            all_kpi = pd.merge(shooting, pd.merge(possession , passes, how='inner', on=['Date' , 'Opponent']), how='inner', on=['Date' , 'Opponent'],)
            team_data = matches.merge(all_kpi,on=['Date' , 'Opponent'])
            print("Marged data for: ", f'{team_name}'  ,'\n')

            all_matches = pd.concat([all_matches, team_data], ignore_index=True)
            print("Waiting for 5 seconds...")
            time.sleep(5)
            
            print("End of proccess" ,'\n')

all_matches.columns = [i.lower() for i in all_matches.columns]           
all_matches['round_1'] = all_matches['round'].apply(lambda x: x.split(' ')[1] if 'Matchweek' in x else 0).astype(int)     
all_matches["date"] = pd.to_datetime(all_matches["date"])
all_matches.to_pickle('all_matches_2324.pkl')
# team_urls
# Out:
# 16/09/2023 18:04:56
# ('2023-2024', '11/Serie-A-Stats')
#
# https://fbref.com/en/comps/11/Serie-A-Stats
#
# https://fbref.com/en/squads/d609edc0/2023-2024/Internazionale-Stats
# Calling  https://fbref.com/en/squads/d609edc0/2023-2024/Internazionale-Stats  result:  <Response [200]>
#
# Step 1: matches data for:  Internazionale
#
# Step 1 ended: Internazionale
#
# Step 2: shoots data for:  Internazionale
#
# Step 2 ended: Internazionale
#
# Step 3: possession data for:  Internazionale
#
# Step 3 ended: Internazionale
#
# Step 4: passes data for:  Internazionale
#
# Step 4 ended: Internazionale
#
# Marged data for:  Internazionale
#
# Waiting for 5 seconds...
# End of proccess
#
# https://fbref.com/en/squads/dc56fe14/2023-2024/Milan-Stats
# Calling  https://fbref.com/en/squads/dc56fe14/2023-2024/Milan-Stats  result:  <Response [200]>
#
# Step 1: matches data for:  Milan
#
# Step 1 ended: Milan
#
# Step 2: shoots data for:  Milan
#
# Step 2 ended: Milan
#
# Step 3: possession data for:  Milan
#
# Step 3 ended: Milan
#
# Step 4: passes data for:  Milan
#
# Step 4 ended: Milan
#
# Marged data for:  Milan
#
# Waiting for 5 seconds...
# End of proccess
#
# https://fbref.com/en/squads/e0652b02/2023-2024/Juventus-Stats
# Calling  https://fbref.com/en/squads/e0652b02/2023-2024/Juventus-Stats  result:  <Response [200]>
#
# Step 1: matches data for:  Juventus
#
# Step 1 ended: Juventus
#
# Step 2: shoots data for:  Juventus
#
# Step 2 ended: Juventus
#
# Step 3: possession data for:  Juventus
#
# Step 3 ended: Juventus
#
# Step 4: passes data for:  Juventus
#
# Step 4 ended: Juventus
#
# Marged data for:  Juventus
#
# Waiting for 5 seconds...
# End of proccess
#
# https://fbref.com/en/squads/ffcbe334/2023-2024/Lecce-Stats
# Calling  https://fbref.com/en/squads/ffcbe334/2023-2024/Lecce-Stats  result:  <Response [200]>
#
# Step 1: matches data for:  Lecce
#
# Step 1 ended: Lecce
#
# Step 2: shoots data for:  Lecce
#
# Step 2 ended: Lecce
#
# Step 3: possession data for:  Lecce
#
# Step 3 ended: Lecce
#
# Step 4: passes data for:  Lecce
#
# Step 4 ended: Lecce
#
# Marged data for:  Lecce
#
# Waiting for 5 seconds...
# End of proccess
#
# https://fbref.com/en/squads/922493f3/2023-2024/Atalanta-Stats
# Calling  https://fbref.com/en/squads/922493f3/2023-2024/Atalanta-Stats  result:  <Response [200]>
#
# Step 1: matches data for:  Atalanta
#
# Step 1 ended: Atalanta
#
# Step 2: shoots data for:  Atalanta
#
# Step 2 ended: Atalanta
#
# Step 3: possession data for:  Atalanta
#
# Step 3 ended: Atalanta
#
# Step 4: passes data for:  Atalanta
#
# Step 4 ended: Atalanta
#
# Marged data for:  Atalanta
#
# Waiting for 5 seconds...
# End of proccess
#
# https://fbref.com/en/squads/d48ad4ff/2023-2024/Napoli-Stats
# Calling  https://fbref.com/en/squads/d48ad4ff/2023-2024/Napoli-Stats  result:  <Response [200]>
#
# Step 1: matches data for:  Napoli
#
# Step 1 ended: Napoli
#
# Step 2: shoots data for:  Napoli
#
# Step 2 ended: Napoli
#
# Step 3: possession data for:  Napoli
#
# Step 3 ended: Napoli
#
# Step 4: passes data for:  Napoli
#
# Step 4 ended: Napoli
#
# Marged data for:  Napoli
#
# Waiting for 5 seconds...
# End of proccess
#
# https://fbref.com/en/squads/0e72edf2/2023-2024/Hellas-Verona-Stats
# Calling  https://fbref.com/en/squads/0e72edf2/2023-2024/Hellas-Verona-Stats  result:  <Response [200]>
#
# Step 1: matches data for:  Hellas Verona
#
# Step 1 ended: Hellas Verona
#
# Step 2: shoots data for:  Hellas Verona
#
# Step 2 ended: Hellas Verona
#
# Step 3: possession data for:  Hellas Verona
#
# Step 3 ended: Hellas Verona
#
# Step 4: passes data for:  Hellas Verona
#
# Step 4 ended: Hellas Verona
#
# Marged data for:  Hellas Verona
#
# Waiting for 5 seconds...
# End of proccess
#
# https://fbref.com/en/squads/421387cf/2023-2024/Fiorentina-Stats
# Calling  https://fbref.com/en/squads/421387cf/2023-2024/Fiorentina-Stats  result:  <Response [200]>
#
# Step 1: matches data for:  Fiorentina
#
# Step 1 ended: Fiorentina
#
# Step 2: shoots data for:  Fiorentina
#
# Step 2 ended: Fiorentina
#
# Step 3: possession data for:  Fiorentina
#
# Step 3 ended: Fiorentina
#
# Step 4: passes data for:  Fiorentina
#
# Step 4 ended: Fiorentina
#
# Marged data for:  Fiorentina
#
# Waiting for 5 seconds...
# End of proccess
#
# https://fbref.com/en/squads/1d8099f8/2023-2024/Bologna-Stats
# Calling  https://fbref.com/en/squads/1d8099f8/2023-2024/Bologna-Stats  result:  <Response [200]>
#
# Step 1: matches data for:  Bologna
#
# Step 1 ended: Bologna
#
# Step 2: shoots data for:  Bologna
#
# Step 2 ended: Bologna
#
# Step 3: possession data for:  Bologna
#
# Step 3 ended: Bologna
#
# Step 4: passes data for:  Bologna
#
# Step 4 ended: Bologna
#
# Marged data for:  Bologna
#
# Waiting for 5 seconds...
# End of proccess
#
# https://fbref.com/en/squads/6a7ad59d/2023-2024/Frosinone-Stats
# Calling  https://fbref.com/en/squads/6a7ad59d/2023-2024/Frosinone-Stats  result:  <Response [200]>
#
# Step 1: matches data for:  Frosinone
#
# Step 1 ended: Frosinone
#
# Step 2: shoots data for:  Frosinone
#
# Step 2 ended: Frosinone
#
# Step 3: possession data for:  Frosinone
#
# Step 3 ended: Frosinone
#
# Step 4: passes data for:  Frosinone
#
# Step 4 ended: Frosinone
#
# Marged data for:  Frosinone
#
# Waiting for 5 seconds...
# End of proccess
#
# https://fbref.com/en/squads/105360fe/2023-2024/Torino-Stats
# Calling  https://fbref.com/en/squads/105360fe/2023-2024/Torino-Stats  result:  <Response [200]>
#
# Step 1: matches data for:  Torino
#
# Step 1 ended: Torino
#
# Step 2: shoots data for:  Torino
#
# Step 2 ended: Torino
#
# Step 3: possession data for:  Torino
#
# Step 3 ended: Torino
#
# Step 4: passes data for:  Torino
#
# Step 4 ended: Torino
#
# Marged data for:  Torino
#
# Waiting for 5 seconds...
# End of proccess
#
# https://fbref.com/en/squads/7213da33/2023-2024/Lazio-Stats
# Calling  https://fbref.com/en/squads/7213da33/2023-2024/Lazio-Stats  result:  <Response [200]>
#
# Step 1: matches data for:  Lazio
#
# Step 1 ended: Lazio
#
# Step 2: shoots data for:  Lazio
#
# Step 2 ended: Lazio
#
# Step 3: possession data for:  Lazio
#
# Step 3 ended: Lazio
#
# Step 4: passes data for:  Lazio
#
# Step 4 ended: Lazio
#
# Marged data for:  Lazio
#
# Waiting for 5 seconds...
# End of proccess
#
# https://fbref.com/en/squads/e2befd26/2023-2024/Sassuolo-Stats
# Calling  https://fbref.com/en/squads/e2befd26/2023-2024/Sassuolo-Stats  result:  <Response [200]>
#
# Step 1: matches data for:  Sassuolo
#
# Step 1 ended: Sassuolo
#
# Step 2: shoots data for:  Sassuolo
#
# Step 2 ended: Sassuolo
#
# Step 3: possession data for:  Sassuolo
#
# Step 3 ended: Sassuolo
#
# Step 4: passes data for:  Sassuolo
#
# Step 4 ended: Sassuolo
#
# Marged data for:  Sassuolo
#
# Waiting for 5 seconds...
# End of proccess
#
# https://fbref.com/en/squads/658bf2de/2023-2024/Genoa-Stats
# Calling  https://fbref.com/en/squads/658bf2de/2023-2024/Genoa-Stats  result:  <Response [200]>
#
# Step 1: matches data for:  Genoa
#
# Step 1 ended: Genoa
#
# Step 2: shoots data for:  Genoa
#
# Step 2 ended: Genoa
#
# Step 3: possession data for:  Genoa
#
# Step 3 ended: Genoa
#
# Step 4: passes data for:  Genoa
#
# Step 4 ended: Genoa
#
# Marged data for:  Genoa
#
# Waiting for 5 seconds...
# End of proccess
#
# https://fbref.com/en/squads/21680aa4/2023-2024/Monza-Stats
# Calling  https://fbref.com/en/squads/21680aa4/2023-2024/Monza-Stats  result:  <Response [200]>
#
# Step 1: matches data for:  Monza
#
# Step 1 ended: Monza
#
# Step 2: shoots data for:  Monza
#
# Step 2 ended: Monza
#
# Step 3: possession data for:  Monza
#
# Step 3 ended: Monza
#
# Step 4: passes data for:  Monza
#
# Step 4 ended: Monza
#
# Marged data for:  Monza
#
# Waiting for 5 seconds...
# End of proccess
#
# https://fbref.com/en/squads/c5577084/2023-2024/Salernitana-Stats
# Calling  https://fbref.com/en/squads/c5577084/2023-2024/Salernitana-Stats  result:  <Response [200]>
#
# Step 1: matches data for:  Salernitana
#
# Step 1 ended: Salernitana
#
# Step 2: shoots data for:  Salernitana
#
# Step 2 ended: Salernitana
#
# Step 3: possession data for:  Salernitana
#
# Step 3 ended: Salernitana
#
# Step 4: passes data for:  Salernitana
#
# Step 4 ended: Salernitana
#
# Marged data for:  Salernitana
#
# Waiting for 5 seconds...
# End of proccess
#
# https://fbref.com/en/squads/04eea015/2023-2024/Udinese-Stats
# Calling  https://fbref.com/en/squads/04eea015/2023-2024/Udinese-Stats  result:  <Response [200]>
#
# Step 1: matches data for:  Udinese
#
# Step 1 ended: Udinese
#
# Step 2: shoots data for:  Udinese
#
# Step 2 ended: Udinese
#
# Step 3: possession data for:  Udinese
#
# Step 3 ended: Udinese
#
# Step 4: passes data for:  Udinese
#
# Step 4 ended: Udinese
#
# Marged data for:  Udinese
#
# Waiting for 5 seconds...
# End of proccess
#
# https://fbref.com/en/squads/cf74a709/2023-2024/Roma-Stats
# Calling  https://fbref.com/en/squads/cf74a709/2023-2024/Roma-Stats  result:  <Response [200]>
#
# Step 1: matches data for:  Roma
#
# Step 1 ended: Roma
#
# Step 2: shoots data for:  Roma
#
# Step 2 ended: Roma
#
# Step 3: possession data for:  Roma
#
# Step 3 ended: Roma
#
# Step 4: passes data for:  Roma
#
# Step 4 ended: Roma
#
# Marged data for:  Roma
#
# Waiting for 5 seconds...
# End of proccess
#
# https://fbref.com/en/squads/c4260e09/2023-2024/Cagliari-Stats
# Calling  https://fbref.com/en/squads/c4260e09/2023-2024/Cagliari-Stats  result:  <Response [200]>
#
# Step 1: matches data for:  Cagliari
#
# Step 1 ended: Cagliari
#
# Step 2: shoots data for:  Cagliari
#
# Step 2 ended: Cagliari
#
# Step 3: possession data for:  Cagliari
#
# Step 3 ended: Cagliari
#
# Step 4: passes data for:  Cagliari
#
# Step 4 ended: Cagliari
#
# Marged data for:  Cagliari
#
# Waiting for 5 seconds...
# End of proccess
#
# https://fbref.com/en/squads/a3d88bd8/2023-2024/Empoli-Stats
# Calling  https://fbref.com/en/squads/a3d88bd8/2023-2024/Empoli-Stats  result:  <Response [200]>
#
# Step 1: matches data for:  Empoli
#
# Step 1 ended: Empoli
#
# Step 2: shoots data for:  Empoli
#
# Step 2 ended: Empoli
#
# Step 3: possession data for:  Empoli
#
# Step 3 ended: Empoli
#
# Step 4: passes data for:  Empoli
#
# Step 4 ended: Empoli
#
# Marged data for:  Empoli
#
# Waiting for 5 seconds...
# End of proccess

# %%
# str(data)
data_poss
df = all_matches.copy()
# df[df.season=="2023-2024"].head()

# %%
# df.team.value_counts()
df[df.team=='Fiorentina']
# Out:
#          date   time     comp           round  day venue result   gf   ga  \
# 23 2023-08-19  20:45  Serie A     Matchweek 1  Sat  Away      W  4.0  1.0
# 24 2023-08-24  19:00  Conf Lg  Play-off round  Thu  Away      L  0.0  1.0
# 25 2023-08-27  18:30  Serie A     Matchweek 2  Sun  Home      D  2.0  2.0
# 26 2023-08-31  20:00  Conf Lg  Play-off round  Thu  Home      W  2.0  0.0
# 27 2023-09-03  18:30  Serie A     Matchweek 3  Sun  Away      L  0.0  4.0
#
#          opponent   xg  xga  poss  attendance              captain formation  \
# 23          Genoa  1.0  0.2  68.0         NaN    Cristiano Biraghi   4-2-3-1
# 24  at Rapid Wien  NaN  NaN   NaN     23000.0    Cristiano Biraghi     4-3-3
# 25          Lecce  1.3  0.3  59.0         NaN  Giacomo Bonaventura   4-2-3-1
# 26  at Rapid Wien  NaN  NaN   NaN     24135.0    Cristiano Biraghi     4-3-3
# 27          Inter  0.4  3.7  60.0         NaN    Cristiano Biraghi   4-2-3-1
#
#                        referee  match report                       notes  \
# 23            Giovanni Ayroldi  Match Report                         NaN
# 24                  Igor Pajač  Match Report                  Leg 1 of 2
# 25  Maria Sole Ferrieri Caputi  Match Report                         NaN
# 26               Novak Simović  Match Report  Leg 2 of 2; Fiorentina won
# 27            Matteo Marchetti  Match Report                         NaN
#
#        season        campionato        team  shoot_sh  shoot_sot  shoot_dist  \
# 23  2023-2024  11/Serie-A-Stats  Fiorentina       9.0        5.0        18.6
# 24  2023-2024  11/Serie-A-Stats  Fiorentina       NaN        NaN         NaN
# 25  2023-2024  11/Serie-A-Stats  Fiorentina      10.0        4.0        13.3
# 26  2023-2024  11/Serie-A-Stats  Fiorentina       NaN        NaN         NaN
# 27  2023-2024  11/Serie-A-Stats  Fiorentina       6.0        2.0        20.5
#
#     shoot_fk  shoot_pk  shoot_pkatt  poss_touches  poss_def pen  poss_def 3rd  \
# 23       0.0         0            0         794.0          69.0         279.0
# 24       NaN         0            0           NaN           NaN           NaN
# 25       1.0         0            0         592.0          39.0         172.0
# 26       NaN         1            1           NaN           NaN           NaN
# 27       0.0         0            0         639.0          66.0         215.0
#
#     poss_mid 3rd  poss_att 3rd  poss_att pen  poss_live  poss_att  poss_succ  \
# 23         346.0         174.0          24.0      794.0      18.0       10.0
# 24           NaN           NaN           NaN        NaN       NaN        NaN
# 25         312.0         117.0          21.0      592.0      25.0       12.0
# 26           NaN           NaN           NaN        NaN       NaN        NaN
# 27         313.0         117.0          12.0      639.0      24.0       10.0
#
#     poss_succ%  poss_tkld  poss_tkld%  poss_carries  poss_totdist  \
# 23        55.6        6.0        33.3         525.0        2278.0
# 24         NaN        NaN         NaN           NaN           NaN
# 25        48.0       10.0        40.0         383.0        2146.0
# 26         NaN        NaN         NaN           NaN           NaN
# 27        41.7       12.0        50.0         465.0        2220.0
#
#     poss_prgdist  poss_prgc  poss_1/3  poss_cpa  poss_mis  poss_dis  poss_rec  \
# 23        1223.0       23.0      15.0       8.0      13.0       8.0     593.0
# 24           NaN        NaN       NaN       NaN       NaN       NaN       NaN
# 25         993.0       14.0       8.0       3.0       9.0      10.0     386.0
# 26           NaN        NaN       NaN       NaN       NaN       NaN       NaN
# 27        1008.0       16.0      15.0       2.0      11.0       7.0     476.0
#
#     poss_prgr  pass_touches  pass_def pen  pass_def 3rd  pass_mid 3rd  \
# 23       43.0         599.0         694.0          86.3       11368.0
# 24        NaN           NaN           NaN           NaN           NaN
# 25       47.0         393.0         493.0          79.7        8030.0
# 26        NaN           NaN           NaN           NaN           NaN
# 27       32.0         481.0         568.0          84.7        9655.0
#
#     pass_att 3rd  pass_att pen  pass_live  pass_att  pass_succ  pass_succ%  \
# 23        3496.0         246.0      261.0      94.3      253.0       281.0
# 24           NaN           NaN        NaN       NaN        NaN         NaN
# 25        2763.0         128.0      150.0      85.3      204.0       228.0
# 26           NaN           NaN        NaN       NaN        NaN         NaN
# 27        2865.0         171.0      193.0      88.6      210.0       237.0
#
#     pass_tkld  pass_tkld%  pass_carries  pass_totdist  pass_prgdist  \
# 23       90.0        90.0         118.0          76.3             3
# 24        NaN         NaN           NaN           NaN             0
# 25       89.5        61.0          88.0          69.3             2
# 26        NaN         NaN           NaN           NaN             0
# 27       88.6        79.0         100.0          79.0             0
#
#     pass_prgc  pass_1/3  pass_cpa  pass_mis  pass_dis  pass_rec  pass_prgr  \
# 23        0.4       0.8       6.0      37.0       5.0       0.0       44.0
# 24        NaN       NaN       NaN       NaN       NaN       NaN        NaN
# 25        1.3       1.3       9.0      28.0      11.0       4.0       47.0
# 26        NaN       NaN       NaN       NaN       NaN       NaN        NaN
# 27        0.3       0.7       4.0      28.0       5.0       2.0       32.0
#
#     round_1
# 23        1
# 24        0
# 25        2
# 26        0
# 27        3

# %%
# df['round_1'] = df["Round"].apply(lambda x: x[-1:] if 'Matchweek' in x else pd.NaT)
df['round_1'] = df['Round'].apply(lambda x: x.split(' ')[1] if 'Matchweek' in x else 0).astype(int)
# df.head(2)
# df['round_1'] = df['round_1'].astype(int)
# df[df['round_1'] == '0']
# df.Comp.unique()
# df['Date'] = pd.to_datetime(df['Date'])
df.round_1.dtypes
# df.head()
# Out:
# dtype('int32')

# %%
all_matches.columns
# Out:
# Index(['Date', 'Time', 'Comp', 'Round', 'Day', 'Venue', 'Result', 'GF', 'GA',
#        'Opponent', 'xG', 'xGA', 'Poss', 'Attendance', 'Captain', 'Formation',
#        'Referee', 'Match Report', 'Notes', 'season', 'team', 'shoot_Sh',
#        'shoot_SoT', 'shoot_Dist', 'shoot_FK', 'shoot_PK', 'shoot_PKatt',
#        'poss_Touches', 'poss_Def Pen', 'poss_Def 3rd', 'poss_Mid 3rd',
#        'poss_Att 3rd', 'poss_Att Pen', 'poss_Live', 'poss_Att', 'poss_Succ',
#        'poss_Succ%', 'poss_Tkld', 'poss_Tkld%', 'poss_Carries', 'poss_TotDist',
#        'poss_PrgDist', 'poss_PrgC', 'poss_1/3', 'poss_CPA', 'poss_Mis',
#        'poss_Dis', 'poss_Rec', 'poss_PrgR', 'pass_Touches', 'pass_Def Pen',
#        'pass_Def 3rd', 'pass_Mid 3rd', 'pass_Att 3rd', 'pass_Att Pen',
#        'pass_Live', 'pass_Att', 'pass_Succ', 'pass_Succ%', 'pass_Tkld',
#        'pass_Tkld%', 'pass_Carries', 'pass_TotDist', 'pass_PrgDist',
#        'pass_PrgC', 'pass_1/3', 'pass_CPA', 'pass_Mis', 'pass_Dis', 'pass_Rec',
#        'pass_PrgR'],
#       dtype='object')

# %%
# all_matches['Round'] = all_matches['Round'].str.split( " " ).str[1]
# all_matches['Round'].dtypes
all_matches.head(2)

# %%
all_matches[(all_matches['team'] == 'Internazionale') & (all_matches['Round'] <3)]
# Out:
# Empty DataFrame
# Columns: [Date, Time, Comp, Round, Day, Venue, Result, GF, GA, Opponent, xG, xGA, Poss, Attendance, Captain, Formation, Referee, Match Report, Notes, season, campionato, team, shoot_Sh, shoot_SoT, shoot_Dist, shoot_FK, shoot_PK, shoot_PKatt, poss_Touches, poss_Def Pen, poss_Def 3rd, poss_Mid 3rd, poss_Att 3rd, poss_Att Pen, poss_Live, poss_Att, poss_Succ, poss_Succ%, poss_Tkld, poss_Tkld%, poss_Carries, poss_TotDist, poss_PrgDist, poss_PrgC, poss_1/3, poss_CPA, poss_Mis, poss_Dis, poss_Rec, poss_PrgR, pass_Touches, pass_Def Pen, pass_Def 3rd, pass_Mid 3rd, pass_Att 3rd, pass_Att Pen, pass_Live, pass_Att, pass_Succ, pass_Succ%, pass_Tkld, pass_Tkld%, pass_Carries, pass_TotDist, pass_PrgDist, pass_PrgC, pass_1/3, pass_CPA, pass_Mis, pass_Dis, pass_Rec, pass_PrgR]
# Index: []
